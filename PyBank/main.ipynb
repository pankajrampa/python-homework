# %%
import pandas as pd

# %%
budget_data = pd.read_csv(r"C:\Users\panka\python-homework\budget_data.csv")

# %%
budget_data.head(10)
# Out:
#        Date  Profit/Losses
# 0  Jan-2010         867884
# 1  Feb-2010         984655
# 2  Mar-2010         322013
# 3  Apr-2010         -69417
# 4  May-2010         310503
# 5  Jun-2010         522857
# 6  Jul-2010        1033096
# 7  Aug-2010         604885
# 8  Sep-2010        -216386
# 9  Oct-2010         477532

# %%
budget_data
# Out:
#         Date  Profit/Losses
# 0   Jan-2010         867884
# 1   Feb-2010         984655
# 2   Mar-2010         322013
# 3   Apr-2010         -69417
# 4   May-2010         310503
# ..       ...            ...
# 81  Oct-2016         102685
# 82  Nov-2016         795914
# 83  Dec-2016          60988
# 84  Jan-2017         138230
# 85  Feb-2017         671099
#
# [86 rows x 2 columns]

# %%
len(budget_data)
# Out:
# 86
